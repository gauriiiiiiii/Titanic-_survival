# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("/content/TITANIC SURVIVAL PREDICTION.csv")

# %%
df.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0          892         0       3
# 1          893         1       3
# 2          894         0       2
# 3          895         0       3
# 4          896         1       3
# 5          897         0       3
# 6          898         1       3
# 7          899         0       2
# 8          900         1       3
# 9          901         0       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 0                              Kelly, Mr. James    male  34.5      0      0
# 1              Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                     Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                              Wirz, Mr. Albert    male  27.0      0      0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# 5                    Svensson, Mr. Johan Cervin    male  14.0      0      0
# ...

# %%
df.shape
# Out:
# (418, 12)

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   418.000000  418.000000  418.000000  332.000000  418.000000
# mean   1100.500000    0.363636    2.265550   30.272590    0.447368
# std     120.810458    0.481622    0.841838   14.181209    0.896760
# min     892.000000    0.000000    1.000000    0.170000    0.000000
# 25%     996.250000    0.000000    1.000000   21.000000    0.000000
# 50%    1100.500000    0.000000    3.000000   27.000000    0.000000
# 75%    1204.750000    1.000000    3.000000   39.000000    1.000000
# max    1309.000000    1.000000    3.000000   76.000000    8.000000
#
#             Parch        Fare
# count  418.000000  417.000000
# mean     0.392344   35.627188
# std      0.981429   55.907576
# min      0.000000    0.000000
# 25%      0.000000    7.895800
# 50%      0.000000   14.454200
# 75%      0.000000   31.500000
# max      9.000000  512.329200

# %%
# Encode categorical variables
from sklearn.preprocessing import LabelEncoder
le_sex = LabelEncoder()
le_embarked = LabelEncoder()
df['Sex'] = le_sex.fit_transform(df['Sex'])
df['Embarked'] = le_embarked.fit_transform(df['Embarked'])

# %%
df['Survived'].value_counts()
# Out:
# Survived
# 0    266
# 1    152
# Name: count, dtype: int64

# %%
#let's visualize the count of survivals wrt pclass
sns.countplot(x=df['Survived'])
# Out:
# <Axes: xlabel='Survived', ylabel='count'>

# %%
#let's visualize the count of survivals wrt Gender
sns.countplot(x=df['Sex'], hue=df['Survived'])
# Out:
# <Axes: xlabel='Sex', ylabel='count'>

# %%
df['Sex'], df['Survived'] #To visually compare who survived based on their sex.
# Out:
# (0      1
#  1      0
#  2      1
#  3      1
#  4      0
#        ..
#  413    1
#  414    0
#  415    1
#  416    1
#  417    1
#  Name: Sex, Length: 418, dtype: int64,
#  0      0
#  1      1
#  2      0
#  3      0
#  4      1
#        ..
#  413    0
#  414    1
#  415    0
#  416    0
#  417    0
#  Name: Survived, Length: 418, dtype: int64)

# %%
sns.countplot(x=df['Sex'], hue=df["Survived"]) #hue is used to separate data based on categories and display them in different colors on the same graph.
# Out:
# <Axes: xlabel='Sex', ylabel='count'>

# %%
df.isna().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             1
# Cabin          327
# Embarked         0
# dtype: int64

# %%
df_final = df
df_final.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0          892         0       3
# 1          893         1       3
# 2          894         0       2
# 3          895         0       3
# 4          896         1       3
# 5          897         0       3
# 6          898         1       3
# 7          899         0       2
# 8          900         1       3
# 9          901         0       3
#
#                                            Name  Sex  SibSp  Parch     Ticket  \
# 0                              Kelly, Mr. James    1      0      0     330911
# 1              Wilkes, Mrs. James (Ellen Needs)    0      1      0     363272
# 2                     Myles, Mr. Thomas Francis    1      0      0     240276
# 3                              Wirz, Mr. Albert    1      0      0     315154
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)    0      1      1    3101298
# 5                    Svensson, Mr. Johan Cervin    1      0      0       7538
# ...

# %%
# Split the data into training and testing sets
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size = 0.2, random_state = 0)

# %%
# Algo

# %%
# Logistic Regression
log_model = LogisticRegression(max_iter=1000)
log_model.fit(X_train , Y_train)
log_preds = log_model.predict(X_test)

# %%
# Random Forest
from sklearn.ensemble import RandomForestClassifier
rf = RandomForestClassifier(random_state=42)
rf.fit(X_train, Y_train)
rf = rf.predict(X_test)

# %%
#Support Vector Machine (SVM)
from sklearn.svm import SVC
svm = SVC(kernel='linear')
svm.fit(X_train, Y_train)
svm = svm.predict(X_test)

# %%
# 📊 Evaluation
from sklearn.metrics import accuracy_score, classification_report

print("🔹 SVM Accuracy:", accuracy_score(Y_test, svm))
print("🔹 Random Forest Accuracy:", accuracy_score(Y_test, rf))
print("🔹 Logistic Regression Accuracy:", accuracy_score(Y_test, log_preds))
print("\n📄 Classification Report - SVM:\n", classification_report(Y_test, svm))
# Out:
# 🔹 SVM Accuracy: 1.0
# 🔹 Random Forest Accuracy: 1.0
# 🔹 Logistic Regression Accuracy: 1.0
#
# 📄 Classification Report - SVM:
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        45
#            1       1.00      1.00      1.00        39
#
#     accuracy                           1.00        84
#    macro avg       1.00      1.00      1.00        84
# weighted avg       1.00      1.00      1.00        84

# %%
# Define features (X) and target (Y)
X = df.drop('Survived', axis=1)
Y = df['Survived']
